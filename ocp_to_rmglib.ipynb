# %% [markdown]
# # OCP Conversion Notebook
# This notebook takes data from the open catalyst project and converts it to an rmg thermo library. Enthalpies are from BEs, entropies are from platinum, with the assumption that entropy changes are negligible

# %%
import lmdb
import pickle
import yaml
from ase import Atoms
from ase.visualize import view
import ase.data 
from ocpmodels.datasets import LmdbDataset

# %%
oc20_path = "/work/westgroup/opencatalyst/"

data_dict = pickle.load(open(f"{oc20_path}oc20_data_mapping.pkl","rb"))
print(len(data_dict))
# Out:
# 1281041

# %% [markdown]
# ## load the pickle files we created

# %%
with open('pt_id_lookup.yaml', 'r') as f:
    pt111_sids = yaml.load(f,Loader=yaml.FullLoader)
    
with open('cu_id_lookup.yaml', 'r') as f:
    cu111_sids = yaml.load(f,Loader=yaml.FullLoader)

with open('ni_id_lookup.yaml', 'r') as f:
    ni111_sids = yaml.load(f,Loader=yaml.FullLoader)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 with open('pt_id_lookup.yaml', 'r') as f:
#       2     pt111_sids = yaml.load(f,Loader=yaml.FullLoader)
#       4 with open('cu_id_lookup.yaml', 'r') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pt_id_lookup.yaml'

# %%
with open('Pt111_species_all.pkl', 'rb') as f:
    pt111_dict = pickle.load(f)
    
with open('Cu111_species_all.pkl', 'rb') as f:
    cu111_dict = pickle.load(f)

with open('Ni111_species_all.pkl', 'rb') as f:
    ni111_dict = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 with open('Pt111_species_all.pkl', 'rb') as f:
#       2     pt111_dict = pickle.load(f)
#       4 with open('Cu111_species_all.pkl', 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Pt111_species_all.pkl'

# %%
for key, value in pt_sids.items():
    if key in pt111_dict.keys():
        pass
    elif key in ptval111_dict.keys():
        pass
    else: 
        print(value[0], value[1])

# %%
print(len(ptval111_dict.keys()) + len(pt111_dict.keys()))
print(len(cuval111_dict.keys()) + len(cu111_dict.keys()))
print(len(nival111_dict.keys()) + len(ni111_dict.keys()))

# %%
for key, value in cu111_dict.items():
    if value["miller_index"] == (1, 1, 1):
        print(value["ads_symbol"], value["miller_index"], key)

# %% [markdown]
# ## add the species name to the dictionary for easy id

# %%
for key, value in pt_sids.items():
    if key in pt111_dict.keys():
        pt111_dict[key]["ads_symbol"] = pt_sids[key][0]

for key, value in cu_sids.items():
    if key in cu111_dict.keys():
        cu111_dict[key]["ads_symbol"] = cu_sids[key][0]
        
for key, value in ni_sids.items():
    if key in ni111_dict.keys():
        ni111_dict[key]["ads_symbol"] = ni_sids[key][0]

# %% [markdown]
# ## take an example molecule (oh on copper 111) *OH (1, 1, 1)

# %%
cu111_dict[588184].keys()

# %%
atomic_nums = cu111_dict[588184]["atomic_numbers"]
positions = cu111_dict[588184]["pos_relaxed"]

# %%
list(positions[1])

# %%
geometry = Atoms(atomic_nums, positions=positions)
view(geometry , viewer='x3d')

# %%
geometry = Atoms(atomic_nums, positions=positions)
view(geometry.repeat((5,5,1)) , viewer='x3d')

# %%
# atomic_nums2 = []
# positions2 = []
# highest_position
# for idx, atom_n in enumerate(atomic_nums): 
# #     if atom_n != 29:
        
# #         pass
# #     else:
#         atomic_nums2.append(int(atomic_nums[idx]))
#         positions2.append(list(positions[idx]))

# geometry2 = Atoms(atomic_nums2, positions=positions2)
# geometry

# %%
type(stacked)
# Out:
# ase.atoms.Atoms

# %%
from ase.build import stack

geometry2 = Atoms(atomic_nums, positions=positions)
del geometry2[[atom.index for atom in geometry2 if atom.symbol=='Cu']]
stacked = stack(
    geometry, 
    geometry, 
    axis=1, 
    cell=None, 
    fix=0.5, 
    maxstrain=1, 
    distance=2.0, 
    reorder=False, 
    output_strained=False
)
del stacked[[atom.index for atom in stacked if atom.symbol!='Cu']]

view(stacked , viewer='x3d')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 169
#          Function evaluations: 269
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="-2.65 1.50 -6.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.95 2.25 -2.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.35 0.75 -4.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.65 1.50 -0.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.94 2.27 4.09">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.35 0.75 2.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.95 3.75 -6.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-5.25 4.50 -2.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.65 3.00 -4.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.95 3.75 -0.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.15 4.50 4.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.65 3.00 2.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-5.25 6.00 -6.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.55 6.75 -2.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.95 5.25 -4.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-5.25 6.00 -0.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.53 6.75 4.09">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.95 5.25 2.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.55 8.25 -6.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.65 -0.00 -2.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-5.25 7.50 -4.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.55 8.25 -0.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.61 0.02 4.07">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-5.25 7.50 2.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.05 1.50 -6.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.35 2.25 -2.25">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.25 0.75 -4.37">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.784 0.502 0.200" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.32">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-0.05 1.50 -0.13">
#
#      <

# %%
# print hello 
print_hello()

def print_hello(): 
    print("hello")
# Out:
# hello
