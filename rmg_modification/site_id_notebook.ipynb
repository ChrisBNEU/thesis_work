# %%
import cantera as ct
path_to_cti = "/work/westgroup/ChrisB/_09_cpox_uncertainty/cpox_uncertainty/rh_ocp_211/__compare__doc/rh_cpox_ocp_211.yaml"
gas = ct.Solution(path_to_cti, 'gas')
surf = ct.Interface(path_to_cti, 'surface1', [gas])

# %%
surf.species()[5].thermo.coeffs[6],surf.species()[5].thermo.coeffs[13]
# Out:
# (-26347.7978, -25839.0764)

# %%
# !which conda
# Out:
# /work/westgroup/ChrisB/miniconda3/bin/conda

# %%
from ase.io.trajectory import Trajectory
from IPython.display import HTML
import glob

# %%
trajectories = glob.glob("rmg_db_xyz_files/*.traj")

# %%
def atoms_to_html(atoms):
    'Return the html representation the atoms object as string'

    from tempfile import NamedTemporaryFile

    with NamedTemporaryFile('r+', suffix='.html') as ntf:
        atoms.write(ntf.name, format='html')
        ntf.seek(0)
        html = ntf.read()
    return html

# %%
site_types = {
    '111_fcc_hollow': 6.955,
    '111_hcp_hollow': 7.5,
    '111_bridge': 7.33,
    '111_top': 7.5,
    }

# %%
len(trajectories)
# Out:
# 74

# %% [markdown]
# ones that we've flagged:
#
# - 22: cco-hcp-relax.traj - this one is probably specifically relaxed in the hcp site, check lit.
# - 24: cchc_multidentate - cannot find entry, sites are ambiguous
# - 34: ochch2_bidentate - we  do not have any info for this species in our db, probably not possible with electron counting. only monodentate.
# - 47: cc.traj - the carbon bond to the surface is a double bond, but the actual structure looks like the atoms are in the hollow site, not the bridge. may need to estimate and then see which one is closer.
# - 48: ch2cch3.traj - could not find this species. also has ambiguous sites
# - 51: ch3oco.traj - could not find this molecule
# - 54: chchc_tridentate - could not find this molecule
# - 57: chcch2-atop-relax.traj - couldn't find this molecule
# - 65: chchch-bi.traj - matches index 127, but one of the carbons is double bound the the catalyst. however, both atoms occuppy top sites.
# - 67: chc.traj - bidentate, ambiguous sites (looks like hollow and bridge, but the bond order is double and single, respectively)
# - 68: mono-cch2.traj: already recorded at a bridge site.
# - 72: och3.traj - single bond between surface and oxygen, but occuppies hollow site.

# %%
len(trajectories)
# Out:
# 74

# %%
traj_num = 73
traj_file = trajectories[traj_num]
print(traj_file)
traj = Trajectory(traj_file)
tbut_html = atoms_to_html(traj[-1])
display(HTML(tbut_html))
# Out:
# rmg_db_xyz_files/pt111.traj
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 8.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.83 0.00 8.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
# ...

# %%
search_str = '/ch2.traj'
for traj in trajectories:
    if search_str in traj: 
        traj_file = traj
        print(traj_file)
        traj = Trajectory(traj_file)
        tbut_html = atoms_to_html(traj[-1])
        display(HTML(tbut_html))
        break
# Out:
# rmg_db_xyz_files/ch2.traj
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="1.41 0.82 10.81">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.24 0.82 10.81">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
# ...

# %%
search_str = '/h2coh.traj'
for traj in trajectories:
    if search_str in traj: 
        traj_file = traj
        print(traj_file)
        traj = Trajectory(traj_file)
        tbut_html = atoms_to_html(traj[-1])
        display(HTML(tbut_html))
        break
# Out:
# rmg_db_xyz_files/h2coh.traj
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 8.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.83 0.00 8.50">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.816 0.816 0.878" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.36">
#
#       </Sphere>
#
#      </Shape>
#
# ...

# %%
traj_file = "./rmg_db_xyz_files/structuredoc/cho_ni.traj"
print(traj_file)
traj = Trajectory(traj_file)
tbut_html = atoms_to_html(traj[-1])
display(HTML(tbut_html))
# Out:
# ./rmg_db_xyz_files/structuredoc/cho_ni.traj
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 10.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.46 0.00 10.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
# ...

# %%
traj_file = "./rmg_db_xyz_files/structuredoc/cooh_ni.traj"
print(traj_file)
traj = Trajectory(traj_file)
tbut_html = atoms_to_html(traj[-1])
display(HTML(tbut_html))
# Out:
# ./rmg_db_xyz_files/structuredoc/cooh_ni.traj
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 10.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="2.46 0.00 10.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.314 0.816 0.314" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="1.24">
#
#       </Sphere>
#
# ...

# %%
1
# Out:
# 1
